# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# d_acc_all = np.load("/Users/deepakprabakar/Desktop/Other_Projects/DTN/saves/d_acc_all.npy")
d_loss_all = np.load("/Users/deepakprabakar/Desktop/Other_Projects/DTN/saves/d_loss_all.npy")
# g_acc_all = np.load("/Users/deepakprabakar/Desktop/Other_Projects/DTN/saves/g_acc_all.npy")
g_loss_all = np.load("/Users/deepakprabakar/Desktop/Other_Projects/DTN/saves/g_loss_all.npy")

# %%
plt.plot(d_loss_all)
plt.plot(g_loss_all)
